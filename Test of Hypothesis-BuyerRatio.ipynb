# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('BuyerRatio.csv')

# %%
print(data.head())
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
print(data.describe())
# Out:
#              East         West        North       South
# count    2.000000     2.000000     2.000000    2.000000
# mean   242.500000   832.500000   743.500000  410.000000
# std    272.236111   976.514465   866.205807  480.832611
# min     50.000000   142.000000   131.000000   70.000000
# 25%    146.250000   487.250000   437.250000  240.000000
# 50%    242.500000   832.500000   743.500000  410.000000
# 75%    338.750000  1177.750000  1049.750000  580.000000
# max    435.000000  1523.000000  1356.000000  750.000000

# %%
data= np.array([data["East"],data["West"], data["North"], data["South"]])
data
# Out:
# array([[  50,  435],
#        [ 142, 1523],
#        [ 131, 1356],
#        [  70,  750]], dtype=int64)

# %%
data = pd.DataFrame({
    'Observed Values': ['Males', 'Females'],
    'East': [50, 435],
    'West': [142, 1523],
    'North': [131, 1356],
    'South': [70, 750]
})

# Set 'Observed Values' as the index
data.set_index('Observed Values', inplace=True)

# Transpose the DataFrame for easy plotting
data_transposed = data.T

# Create histograms for each category
data_transposed.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Histogram of Observed Values by Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.show()

# %%
# Create a DataFrame with the provided data
data = pd.DataFrame({
    'Observed Values': ['Males', 'Females'],
    'East': [50, 435],
    'West': [142, 1523],
    'North': [131, 1356],
    'South': [70, 750]
})
# Set 'Observed Values' as the index
data.set_index('Observed Values', inplace=True)

# Transpose the DataFrame for easy plotting
data_transposed = data.T

# Create a scatter plot for each region
plt.figure(figsize=(10, 6))
for region in data_transposed.columns:
    plt.scatter(data_transposed.index, data_transposed[region], label=region)

plt.title('Scatter Plot of Observed Values by Region')
plt.xlabel('Observed Values')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
# Create a DataFrame with the provided data
data = pd.DataFrame({
    'Observed Values': ['Males', 'Females'],
    'East': [50, 435],
    'West': [142, 1523],
    'North': [131, 1356],
    'South': [70, 750]
})

# Set 'Observed Values' as the index
data.set_index('Observed Values', inplace=True)

# Transpose the DataFrame for easy plotting
data_transposed = data.T

# Create a box plot for each region
plt.figure(figsize=(10, 6))
data_transposed.boxplot()
plt.title('Box Plot of Observed Values by Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.show()

# %%
import scipy.stats as stats
chi2, p, dof, expected = stats.chi2_contingency(df)

# %%
# Print the test results
print("Chi-squared statistic:", chi2)
print("P-value:", p)
# Out:
# Chi-squared statistic: 1.5959455386610577
# P-value: 0.6603094907091882

# %%
# Check if the p-value is less than the significance level (α = 0.05)
if p < 0.05:
    print("Reject the null hypothesis, the male-female buyer ratios are dependent on the regions.")
else:
    print("Fail to reject the null hypothesis, there is no significant evidence to suggest that the male-female buyer ratios are dependent on the regions.")
# Out:
# Fail to reject the null hypothesis, there is no significant evidence to suggest that the male-female buyer ratios are dependent on the regions.
